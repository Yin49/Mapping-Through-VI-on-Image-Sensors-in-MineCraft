# %%
from segmentation import segmentation_task

# %%
from PIL import Image

# %%
train_set = []
left = 960
top = 480
right = 1280
bottom = 800
for i in range(11):
    title = 'test_' + str(i+1) + '.png'
    im = Image.open(title)
    train_set.append(im.crop((left, top, right, bottom)))

# %%
train_set[3]
# Out:
# <PIL.Image.Image image mode=RGBA size=320x320>

# %%
segmentation_task(train_set, 16)
# Out:
# Dataset Summary:
# X Data
#   total size: 16731 units
#   batch size: 16731 units
#   num. batches: 1
# Allocation Model:  DP mixture with K=0. Concentration gamma0= 10.00
# Obs. Data  Model:  Gaussian with fixed zero means, full covariance.
# Obs. Data  Prior:  Wishart on prec matrix Lam
#   E[ CovMat[k] ] =
#   [[0.1 0. ]
#    [0.  0.1]] ...
# Initialization:
#   initname = randexamples
#   K = 16 (number of clusters)
#   seed = 1607680
#   elapsed_time: 0.6 sec
# Learn Alg: memoVB | task  1/1 | alg. seed: 1607680 | data order seed: 8541952
# task_output_path: /Users/inii/CS_141/Final Project/segmentation_test/test_result/1
# MERGE @ lap 1.00: Disabled. Cannot plan merge on first lap. Need valid SS that represent whole dataset.
#     1.000/350 after      1 sec. |   1360.4 MiB | K   16 | loss  5.182935660e+00 |
# MERGE @ lap 2.00 : 7/8 accepted. Ndiff 5223.21. 28 skipped.
#     2.000/350 after      2 sec. |   1376.4 MiB | K    9 | loss  4.570671793e+00 |
# ...
